# %%
import pandas as pd
cities = pd.read_csv("housing.csv")
print(cities.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
# extracting the data we ar interested in
latitude, longitude = cities["latitude"], cities["longitude"]
population, area = cities["population"], cities["households"]


print(population , area)
# Out:
# 0         322.0
# 1        2401.0
# 2         496.0
# 3         558.0
# 4         565.0
#           ...
# 20635     845.0
# 20636     356.0
# 20637    1007.0
# 20638     741.0
# 20639    1387.0
# Name: population, Length: 20640, dtype: float64 0         126.0
# 1        1138.0
# 2         177.0
# 3         219.0
# 4         259.0
#           ...
# 20635     330.0
# 20636     114.0
# 20637     433.0
# 20638     349.0
# 20639     530.0
# Name: households, Length: 20640, dtype: float64

# %%
# to scatter the points, using size and color but without label
import numpy as np
import matplotlib.pyplot as plt
import seaborn
seaborn.set()
plt.scatter(longitude, latitude, label=None, c=np.log10(population),
            cmap='viridis', s=area, linewidth=0, alpha=0.5)
plt.axis(aspect='equal')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.colorbar(label='log$_{10}$(population)')
plt.clim(3, 7)
# now we will craete a legend, we will plot empty lists with the desired size and label
for area in [100, 300, 500]:
    plt.scatter([], [], c='k', alpha=0.3, s=area, label=str(area) + 'km$^2$')
plt.legend(scatterpoints=1, frameon=False, labelspacing=1, title='City Areas')
plt.title(" Population of California Cities")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [3], in <cell line: 8>()
#       5 seaborn.set()
#       6 plt.scatter(longitude, latitude, label=None, c=np.log10(population),
#       7             cmap='viridis', s=area, linewidth=0, alpha=0.5)
# ----> 8 plt.axis(aspect='equal')
#       9 plt.xlabel('Longitude')
#      10 plt.ylabel('Latitude')
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:2371, in axis(emit, *args, **kwargs)
#    2369 @_copy_docstring_and_deprecators(Axes.axis)
#    2370 def axis(*args, emit=True, **kwargs):
# -> 2371     return gca().axis(*args, emit=emit, **kwargs)
#
# File ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py:2099, in _AxesBase.axis(self, emit, *args, **kwargs)
#    2097     self.set_ylim(ymin, ymax, emit=emit, auto=yauto)
#    2098 if kwargs:
# -> 2099     raise TypeError(f"axis() got an unexpected keyword argument "
#    2100                     f"'{next(iter(kwargs))}'")
#    2101 return (*self.get_xlim(), *self.get_ylim())
#
# TypeError: axis() got an unexpected keyword argument 'aspect'

# %%
# extracting the data we ar interested in
latitude, longitude = cities["latitude"], cities["longitude"]
population, area = cities["population"], cities["households"]

# %%
from mpl_toolkits.mplot3d import Axes3D  
import matplotlib.pyplot as plt  
import numpy as np  
  
fig = plt.figure()  
ax = fig.add_subplot(111, projection='3d')  
for c, z in zip(['r', 'g', 'b', 'y'], [30, 20, 10, 0]):  
    longitude = np.arange(100)  
    latitude= np.random.rand(100)  
  
    # You can provide either a single color or an array. To demonstrate this,  
    # the first bar of each set will be colored cyan.  
    cs = [c] * len(longitude)  
    cs[0] = 'c'  
    ax.bar(longitude, latitude, zs=z, zdir='y', color=cs, alpha=0.8)  

ax.set_xlabel('X')  
ax.set_ylabel('Y')  
ax.set_zlabel('Z')  
  
plt.show()

# %%
import pandas as pd
cities = pd.read_csv("housing.csv")
print(cities.head())
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
import matplotlib.pyplot as plt  
from matplotlib import cm  
from matplotlib.ticker import LinearLocator, FormatStrFormatter  
import numpy as np  
  
fig = plt.figure()  
ax = fig.gca(projection='3d')  
  
# Make data.  
X = cities['population']
Y = cities['median_income']
X, Y = np.meshgrid(X, Y)  
R = np.sqrt(X**2 + Y**2)  
Z = np.sin(R)  
  
# Plot the surface.  
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,  
                       linewidth=0, antialiased=False)  
  
# Customize the z axis.  
ax.set_zlim(-1.01, 1.01)  
ax.zaxis.set_major_locator(LinearLocator(10))  
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))  
  
# Add a color bar that maps values to colors.  
fig.colorbar(surf, shrink=0.5, aspect=5)  
  
plt.show()
# Out:
# C:\Users\hjha0\AppData\Local\Temp\ipykernel_4308\3937894300.py:7: MatplotlibDeprecationWarning: Calling gca() with keyword arguments was deprecated in Matplotlib 3.4. Starting two minor releases later, gca() will take no keyword arguments. The gca() function should only be used to get the current axes, or if no axes exist, create new axes with default keyword arguments. To create a new axes with non-default arguments, use plt.axes() or plt.subplot().
#   ax = fig.gca(projection='3d')
